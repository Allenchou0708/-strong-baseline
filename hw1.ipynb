# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd ./drive/MyDrive/NTU_ML2017_Hung-yi-Lee_HW/HW1
# Out:
# /content/drive/MyDrive/NTU_ML2017_Hung-yi-Lee_HW/HW1

# %%
# !pip install numpy
# !pip install pandas
# Out:
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (1.26.4)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (2.2.2)
# Requirement already satisfied: numpy>=1.23.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
import numpy as np
import csv
import sys
import matplotlib.pyplot as plt
from tqdm import tqdm

# %%
import chardet
import pandas as pd

def get_csv_header(file_name) :
    date_list = []

    with open(f"./data/{file_name}","r",newline='', encoding = "big5") as file :
        csv_reader = csv.reader(file)
        next(csv_reader)
        for index,line in enumerate(csv_reader):
            if line[2] not in date_list:
                date_list.append(line[2])

    # np array

    return date_list


def slice_one_day_train(file_name) : # N * 24
    date_list = []

    with open(f"./data/{file_name}","r",newline='', encoding='big5') as file :
        csv_reader = csv.reader(file)
        next(csv_reader)
        for index,line in enumerate(csv_reader):
            line = ["0" if element == "NR" else element for element in line]
            date_list.append(line[3:])

    # np array
    rd_array = np.array(date_list)
    rd_array = rd_array.astype(float)
    return rd_array

def slice_one_day_test(file_name) : # N * 24
    date_list = []

    with open(f"./data/{file_name}","r",newline='', encoding='big5') as file :
        csv_reader = csv.reader(file)
        for index,line in enumerate(csv_reader):
            line = ["0" if element == "NR" else element for element in line]
            date_list.append(line[2:])

    # np array
    rd_array = np.array(date_list)
    rd_array = rd_array.astype(float)
    return rd_array

# %%
# read from csv

pointer_list = get_csv_header("train.csv")

train_raw_data = slice_one_day_train("train.csv")
train_raw_data = train_raw_data.reshape(train_raw_data.size//(20*18*24),20,18,24)
train_raw_data = train_raw_data.transpose(0,2,1,3).reshape(12,18, 20 * 24)

test_raw_data = slice_one_day_test("test.csv")
test_data = test_raw_data.reshape(test_raw_data.size//(18*9),18,9)


print(train_raw_data.shape)
print(test_raw_data.shape)
# Out:
# (12, 18, 480)
# (4320, 9)

# %%
# slice to 9 hour

train_data = []
train_data_label = []

for i in range(train_raw_data.shape[0]):
    for k in range(9,train_raw_data.shape[2]):
        train_data.append(train_raw_data[i,:,k-9:k])
        train_data_label.append(train_raw_data[i,9,k])

train_data = np.array(train_data)
train_data_label = np.array(train_data_label)

print(train_data_label[:40])
# Out:
# [30. 41. 44. 33. 37. 36. 45. 42. 49. 45. 44. 41. 30. 24. 13. 21. 23. 30.
#  30. 22. 18. 13. 13. 11. 22. 25. 34. 38. 50. 53. 43. 43. 45. 46. 32. 16.
#  19. 22. 26. 19.]

# %%
# scalize

train_data_mean = train_data.transpose(1,2,0).mean(axis=2).reshape(1,18,9)
train_data_std = train_data.transpose(1,2,0).std(axis=2).reshape(1,18,9)
train_data = (train_data - train_data_mean)/train_data_std

original_train_data_label_mean = train_data_label.mean()
original_train_data_label_std = train_data_label.std()

train_data_label = (train_data_label - train_data_label.mean()) / train_data_label.std()

test_data_mean = test_data.transpose(1,2,0).mean(axis=2).reshape(1,18,9)
test_data_std = test_data.transpose(1,2,0).std(axis=2).reshape(1,18,9)
test_data = (test_data - test_data_mean)/test_data_std

# %%
# training function

def model(x,w):
  return x @ w

def loss(y_hat,y):
  return np.sum((y_hat - y) ** 2)

def loss_dim(y_hat,y):
  return (y_hat - y) ** 2

def GD(y_hat,y,x, learning_rate, w):
  gradient = x.T @ (y_hat - y) / x.shape[0] * -2 ## 如果是 y_hat - y : 會是 -2; 如果是 y - y_hat : 會是 2
  w = w - learning_rate * gradient
  return w

def ADA(y_hat,y,x, learning_rate, w, history_gradient):
  gradient = x.T @ (y_hat - y) / x.shape[0] * -2
  w = w - learning_rate * gradient

  history_gradient = history_gradient + gradient ** 2
  learning_rate = learning_rate / np.sqrt(history_gradient)

  return w, history_gradient, learning_rate

def SGD(y_hat,y,x, learning_rate, w, sample_size):
  s_index_list = np.random.choice(list(range(x.shape[0])),sample_size,replace=False)
  this_x = x[s_index_list,:]
  this_y = y[s_index_list]
  this_y_hat = y_hat[s_index_list]
  gradient = this_x.T @ (this_y_hat - this_y) / this_x.shape[0] * -2
  w = w - learning_rate * gradient
  return w

# %%
# choose input (pointer,hour,power)

# para_list = []

# for i in range(18):
#   for j in range(9):
#     para_list.append([i,j,1])

para_list = [
    [2,2,1],
    [2,3,1],
    [2,4,1],
    [2,5,1],
    [2,6,1],
    [2,7,1],
    [2,8,1],
    [4,8,1],
    [7,7,1],
    [7,8,1],
    [8,1,1],
    [8,2,1],
    [8,3,1],
    [8,4,1],
    [8,5,1],
    [8,6,1],
    [8,7,1],
    [8,8,1],
    [9,3,1],
    [9,4,1],
    [9,5,1],
    [9,6,1],
    [9,7,1],
    [9,8,1],
    [12,7,1]
]


# para_list = [
#     [2,2,1],
#     [2,3,1],
#     [2,4,1],
#     [2,5,1],
#     [2,6,1],
#     [2,7,1],
#     [2,8,1],
#     [4,8,5],
#     [7,7,5],
#     [7,8,5],
#     [8,1,5],
#     [8,2,5],
#     [8,3,5],
#     [8,4,5],
#     [8,5,3],
#     [8,6,3],
#     [8,7,1],
#     [8,8,1],
#     [9,3,5],
#     [9,4,5],
#     [9,5,3],
#     [9,6,3],
#     [9,7,1],
#     [9,8,1],
#     [12,7,5]
# ]

# para_list = [
#     [2,2,5],
#     [2,3,5],
#     [2,4,5],
#     [2,5,5],
#     [2,6,5],
#     [2,7,5],
#     [2,8,5],
#     [4,8,5],
#     [7,7,5],
#     [7,8,5],
#     [8,1,5],
#     [8,2,5],
#     [8,3,5],
#     [8,4,5],
#     [8,5,5],
#     [8,6,5],
#     [8,7,5],
#     [8,8,5],
#     [9,3,5],
#     [9,4,5],
#     [9,5,5],
#     [9,6,5],
#     [9,7,5],
#     [9,8,5],
#     [12,7,5]
# ]



def find_max_power(para_list):
  np_para_list = np.array(para_list)
  return np.max(np_para_list[:,2])

def selection_list(para_list,max_power):
  np_para_list = np.array(para_list)
  index_list = []
  time_list = []
  power_list = []


  for power in range(1,max_power+1):
    mask_array = np_para_list >= power
    mask_array = mask_array[:,2]
    index_list.append(np_para_list[mask_array,0])
    time_list.append(np_para_list[mask_array,1])
    power_list.extend([power for i in np_para_list[mask_array,0]])

  np_power_list = np.array(power_list)

  return index_list,time_list,np_power_list

# %%
# feature selection


index_list,time_list,np_power_list = selection_list(para_list,find_max_power(para_list))



x = train_data[:5650,index_list[0],time_list[0]]
train_data_label = train_data_label[:5650]
test_x = test_data[:,index_list[0],time_list[0]]



for index,i in enumerate(range(1,len(index_list))):
  power = index + 2
  temp_x = train_data[:5650,index_list[i],time_list[i]] ** power
  x = np.concatenate((x,temp_x),axis=1)

b = np.ones(x.shape[0])[:,None]
x = np.concatenate((x,b),axis=1)
test_x = np.concatenate((test_x,np.ones(test_x.shape[0])[:,None]),axis=1)

feature_size = x.shape[1]

print(feature_size)
# Out:
# 26

# %%
#learning setting

learning_rate = np.array([0.0001 for i in range(feature_size)])
history_learning_rate = np.array([0 for i in range(feature_size)])

fold_n = 5
epoch = 10000

sample = 100

# %%
#好像不是傳旨ㄟ

# %%
# training



train_loss_list_total = []
val_loss_list_total = []


for index in range(fold_n) :
  batch_list = list(range(fold_n))
  batch_list.remove(index)

  np.random.seed(42)
  w = np.random.rand(x.shape[1])

  train_x = x.reshape(fold_n,-1,feature_size)[batch_list,:,:]
  train_x = train_x.reshape(-1,feature_size)
  train_y = train_data_label.reshape(fold_n,-1)[batch_list,:]
  train_y = train_y.reshape(-1)

  val_x = x.reshape(fold_n,-1,feature_size)[index,:,:]
  val_x = val_x.reshape(-1,feature_size)
  val_y = train_data_label.reshape(fold_n,-1)[index,:]
  val_y = val_y.reshape(-1)


  train_loss_list = []
  val_loss_list = []

  # print(train_x.shape)

  learning_rate = np.array([0.01 for i in range(feature_size)])
  history_gradient = np.array([0 for i in range(feature_size)])



  for index in tqdm(range(epoch)):

    train_hypo_y = model(train_x,w)
    train_loss = loss(train_y,train_hypo_y) / train_y.size
    train_loss_list.append(train_loss)

    val_hypo_y = model(val_x,w)
    val_loss = loss(val_y,val_hypo_y) / val_y.size
    val_loss_list.append(val_loss)

    w = GD(train_y,train_hypo_y,train_x, learning_rate, w)
    # w, history_gradient, learning_rate = ADA(train_y,train_hypo_y,train_x, learning_rate, w, history_gradient)

    # w = SGD(train_y,train_hypo_y,train_x, learning_rate, w, sample)

    # print(f"ephoch #{str(index).ljust(5)} loss={round(train_loss,6)}")





  train_loss_list_total.append(train_loss_list)
  val_loss_list_total.append(val_loss_list)
# Out:
# 100%|██████████| 10000/10000 [00:02<00:00, 3713.81it/s]
# 100%|██████████| 10000/10000 [00:02<00:00, 3894.06it/s]
# 100%|██████████| 10000/10000 [00:02<00:00, 4319.11it/s]
# 100%|██████████| 10000/10000 [00:02<00:00, 4147.90it/s]
# 100%|██████████| 10000/10000 [00:04<00:00, 2321.18it/s]

# %%
# drawing

x_axis = np.arange(epoch)

train_loss_axis = np.array(train_loss_list_total)
val_loss_axis = np.array(val_loss_list_total)

train_loss_axis = train_loss_axis.mean(axis=0)
val_loss_axis = val_loss_axis.mean(axis=0)

plt.ylim([0,5])

plt.plot(x_axis,train_loss_axis,"k")
plt.plot(x_axis,val_loss_axis,"r")


plt.show()

# %%
# total training

train_loss = 100
last_loss = 1000000

np.random.seed(42)
w = np.random.rand(x.shape[1])



train_loss_list = []
test_loss = []

learning_rate = np.array([0.01 for i in range(feature_size)])
history_gradient = np.array([0 for i in range(feature_size)])


epoch = 1

while last_loss - train_loss >= 10 ** -6:

  if epoch >= 2:
    last_loss = train_loss

  y = model(x,w)


  train_loss = loss(train_data_label,y) / train_data_label.size
  train_loss_list.append(train_loss)



  w = GD(train_data_label,y,x, learning_rate, w)

  # w, history_gradient, learning_rate = ADA(train_data_label,y,x, learning_rate, w, history_gradient)
  # w = SGD(train_data_label,y,x, learning_rate, w, 2000)

  print(f"ephoch #{str(epoch).ljust(5)} loss={round(train_loss,6)}")


  # history_learning_rate = history_learning_rate + learning_rate ** 2
  # learning_rate = learning_rate / np.sqrt(history_learning_rate)

  epoch+=1
# Out:
# ephoch #1     loss=34.663765
# ephoch #2     loss=22.108016
# ephoch #3     loss=14.528158
# ephoch #4     loss=9.930441
# ephoch #5     loss=7.121424
# ephoch #6     loss=5.386602
# ephoch #7     loss=4.298102
# ephoch #8     loss=3.599599
# ephoch #9     loss=3.13745
# ephoch #10    loss=2.819478
# ephoch #11    loss=2.590311
# ephoch #12    loss=2.41662
# ephoch #13    loss=2.278282
# ephoch #14    loss=2.163095
# ephoch #15    loss=2.063609
# ephoch #16    loss=1.975231
# ephoch #17    loss=1.89509
# ephoch #18    loss=1.821354
# ephoch #19    loss=1.752825
# ephoch #20    loss=1.68869
# ephoch #21    loss=1.628376
# ephoch #22    loss=1.571463
# ephoch #23    loss=1.517623
# ephoch #24    loss=1.466594
# ephoch #25    loss=1.418157
# ephoch #26    loss=1.372125
# ephoch #27    loss=1.328331
# ephoch #28    loss=1.286629
# ephoch #29    loss=1.246884
# ephoch #30    loss=1.208977
# ephoch #31    loss=1.172795
# ephoch #32    loss=1.138235
# ephoch #33    loss=1.105205
# ephoch #34    loss=1.073616
# ephoch #35    loss=1.043387
# ephoch #36    loss=1.014443
# ephoch #37    loss=0.986714
# ephoch #38    loss=0.960136
# ephoch #39    loss=0.934647
# ephoch #40    loss=0.91019
# ephoch #41    loss=0.886714
# ephoch #42    loss=0.864168
# ephoch #43    loss=0.842506
# ephoch #44    loss=0.821685
# ephoch #45    loss=0.801664
# ephoch #46    loss=0.782405
# ephoch #47    loss=0.763871
# ephoch #48    loss=0.746029
# ephoch #49    loss=0.728848
# ephoch #50    loss=0.712297
# ephoch #51    loss=0.696347
# ephoch #52    loss=0.680973
# ephoch #53    loss=0.666149
# ephoch #54    loss=0.65185
# ephoch #55    loss=0.638056
# ephoch #56    loss=0.624743
# ephoch #57    loss=0.611892
# ephoch #58    loss=0.599484
# ephoch #59    loss=0.587499
# ephoch #60    loss=0.575922
# ephoch #61    loss=0.564735
# ephoch #62    loss=0.553923
# ephoch #63    loss=0.543471
# ephoch #64    loss=0.533365
# ephoch #65    loss=0.52359
# ephoch #66    loss=0.514135
# ephoch #67    loss=0.504987
# ephoch #68    loss=0.496134
# ephoch #69    loss=0.487565
# ephoch #70    loss=0.479269
# ephoch #71    loss=0.471236
# ephoch #72    loss=0.463457
# ephoch #73    loss=0.455921
# ephoch #74    loss=0.44862
# ephoch #75    loss=0.441545
# ephoch #76    loss=0.434689
# ephoch #77    loss=0.428043
# ephoch #78    loss=0.4216
# ephoch #79    loss=0.415352
# ephoch #80    loss=0.409292
# ephoch #81    loss=0.403415
# ephoch #82    loss=0.397713
# ephoch #83    loss=0.39218
# ephoch #84    loss=0.386811
# ephoch #85    loss=0.3816
# ephoch #86    loss=0.376541
# ephoch #87    loss=0.37163
# ephoch #88    loss=0.36686
# ephoch #89    loss=0.362228
# ephoch #90    loss=0.357729
# ephoch #91    loss=0.353358
# ephoch #92    loss=0.349111
# ephoch #93    loss=0.344984
# ephoch #94    loss=0.340973
# ephoch #95    loss=0.337074
# ephoch #96    loss=0.333283
# ephoch #97    loss=0.329597
# ephoch #98    loss=0.326012
# ephoch #99    loss=0.322526
# ephoch #100   loss=0.319134
# ephoch #101   loss=0.315834
# ephoch #102   loss=0.312623
# ephoch #103   loss=0.309498
# ephoch #104   loss=0.306457
# ephoch #105   loss=0.303496
# ephoch #106   loss=0.300613
# ephoch #107   loss=0.297806
# ephoch #108   loss=0.295072
# ephoch #109   loss=0.292409
# ephoch #110   loss=0.289815
# ephoch #111   loss=0.287287
# ephoch #112   loss=0.284824
# ephoch #113   loss=0.282423
# ephoch #114   loss=0.280083
# ephoch #115   loss=0.277802
# ephoch #116   loss=0.275578
# ephoch #117   loss=0.273409
# ephoch #118   loss=0.271294
# ephoch #119   loss=0.26923
# ephoch #120   loss=0.267217
# ephoch #121   loss=0.265253
# ephoch #122   loss=0.263336
# ephoch #123   loss=0.261465
# ephoch #124   loss=0.259639
# ephoch #125   loss=0.257856
# ephoch #126   loss=0.256115
# ephoch #127   loss=0.254415
# ephoch #128   loss=0.252754
# ephoch #129   loss=0.251132
# ephoch #130   loss=0.249547
# ephoch #131   loss=0.247998
# ephoch #132   loss=0.246485
# ephoch #133   loss=0.245005
# ephoch #134   loss=0.243559
# ephoch #135   loss=0.242145
# ephoch #136   loss=0.240762
# ephoch #137   loss=0.23941
# ephoch #138   loss=0.238087
# ephoch #139   loss=0.236793
# ephoch #140   loss=0.235527
# ephoch #141   loss=0.234287
# ephoch #142   loss=0.233075
# ephoch #143   loss=0.231887
# ephoch #144   loss=0.230725
# ephoch #145   loss=0.229587
# ephoch #146   loss=0.228472
# ephoch #147   loss=0.227381
# ephoch #148   loss=0.226311
# ephoch #149   loss=0.225264
# ephoch #150   loss=0.224237
# ephoch #151   loss=0.223231
# ephoch #152   loss=0.222245
# ephoch #153   loss=0.221278
# ephoch #154   loss=0.22033
# ephoch #155   loss=0.2194
# ephoch #156   loss=0.218489
# ephoch #157   loss=0.217594
# ephoch #158   loss=0.216717
# ephoch #159   loss=0.215856
# ephoch #160   loss=0.215012
# ephoch #161   loss=0.214182
# ephoch #162   loss=0.213369
# ephoch #163   loss=0.21257
# ephoch #164   loss=0.211785
# ephoch #165   loss=0.211015
# ephoch #166   loss=0.210258
# ephoch #167   loss=0.209515
# ephoch #168   loss=0.208785
# ephoch #169   loss=0.208067
# ephoch #170   loss=0.207362
# ephoch #171   loss=0.206669
# ephoch #172   loss=0.205988
# ephoch #173   loss=0.205318
# ephoch #174   loss=0.20466
# ephoch #175   loss=0.204012
# ephoch #176   loss=0.203375
# ephoch #177   loss=0.202748
# ephoch #178   loss=0.202132
# ephoch #179   loss=0.201526
# ephoch #180   loss=0.200929
# ephoch #181   loss=0.200341
# ephoch #182   loss=0.199763
# ephoch #183   loss=0.199194
# ephoch #184   loss=0.198633
# ephoch #185   loss=0.198082
# ephoch #186   loss=0.197538
# ephoch #187   loss=0.197003
# ephoch #188   loss=0.196475
# ephoch #189   loss=0.195956
# ephoch #190   loss=0.195444
# ephoch #191   loss=0.194939
# ephoch #192   loss=0.194442
# ephoch #193   loss=0.193952
# ephoch #194   loss=0.193469
# ephoch #195   loss=0.192992
# ephoch #196   loss=0.192523
# ephoch #197   loss=0.192059
# ephoch #198   loss=0.191603
# ephoch #199   loss=0.191152
# ephoch #200   loss=0.190707
# ephoch #201   loss=0.190269
# ephoch #202   loss=0.189836
# ephoch #203   loss=0.189409
# ephoch #204   loss=0.188987
# ephoch #205   loss=0.188571
# ephoch #206   loss=0.18816
# ephoch #207   loss=0.187755
# ephoch #208   loss=0.187354
# ephoch #209   loss=0.186959
# ephoch #210   loss=0.186568
# ephoch #211   loss=0.186182
# ephoch #212   loss=0.185801
# ephoch #213   loss=0.185425
# ephoch #214   loss=0.185053
# ephoch #215   loss=0.184686
# ephoch #216   loss=0.184323
# ephoch #217   loss=0.183964
# ephoch #218   loss=0.183609
# ephoch #219   loss=0.183258
# ephoch #220   loss=0.182912
# ephoch #221   loss=0.182569
# ephoch #222   loss=0.18223
# ephoch #223   loss=0.181895
# ephoch #224   loss=0.181564
# ephoch #225   loss=0.181236
# ephoch #226   loss=0.180912
# ephoch #227   loss=0.180592
# ephoch #228   loss=0.180275
# ephoch #229   loss=0.179961
# ephoch #230   loss=0.17965
# ephoch #231   loss=0.179343
# ephoch #232   loss=0.179039
# ephoch #233   loss=0.178738
# ephoch #234   loss=0.178441
# ephoch #235   loss=0.178146
# ephoch #236   loss=0.177854
# ephoch #237   loss=0.177565
# ephoch #238   loss=0.177279
# ephoch #239   loss=0.176996
# ephoch #240   loss=0.176716
# ephoch #241   loss=0.176438
# ephoch #242   loss=0.176164
# ephoch #243   loss=0.175891
# ephoch #244   loss=0.175622
# ephoch #245   loss=0.175355
# ephoch #246   loss=0.17509
# ephoch #247   loss=0.174828
# ephoch #248   loss=0.174568
# ephoch #249   loss=0.174311
# ephoch #250   loss=0.174056
# ephoch #251   loss=0.173803
# ephoch #252   loss=0.173553
# ephoch #253   loss=0.173305
# ephoch #254   loss=0.173059
# ephoch #255   loss=0.172816
# ephoch #256   loss=0.172574
# ephoch #257   loss=0.172335
# ephoch #258   loss=0.172097
# ephoch #259   loss=0.171862
# ephoch #260   loss=0.171629
# ephoch #261   loss=0.171398
# ephoch #262   loss=0.171168
# ephoch #263   loss=0.170941
# ephoch #264   loss=0.170716
# ephoch #265   loss=0.170492
# ephoch #266   loss=0.17027
# ephoch #267   loss=0.17005
# ephoch #268   loss=0.169832
# ephoch #269   loss=0.169616
# ephoch #270   loss=0.169402
# ephoch #271   loss=0.169189
# ephoch #272   loss=0.168978
# ephoch #273   loss=0.168768
# ephoch #274   loss=0.168561
# ephoch #275   loss=0.168354
# ephoch #276   loss=0.16815
# ephoch #277   loss=0.167947
# ephoch #278   loss=0.167746
# ephoch #279   loss=0.167546
# ephoch #280   loss=0.167348
# ephoch #281   loss=0.167151
# ephoch #282   loss=0.166956
# ephoch #283   loss=0.166762
# ephoch #284   loss=0.16657
# ephoch #285   loss=0.166379
# ephoch #286   loss=0.16619
# ephoch #287   loss=0.166002
# ephoch #288   loss=0.165815
# ephoch #289   loss=0.16563
# ephoch #290   loss=0.165446
# ephoch #291   loss=0.165264
# ephoch #292   loss=0.165082
# ephoch #293   loss=0.164903
# ephoch #294   loss=0.164724
# ephoch #295   loss=0.164547
# ephoch #296   loss=0.164371
# ephoch #297   loss=0.164196
# ephoch #298   loss=0.164022
# ephoch #299   loss=0.16385
# ephoch #300   loss=0.163679
# ephoch #301   loss=0.163509
# ephoch #302   loss=0.16334
# ephoch #303   loss=0.163173
# ephoch #304   loss=0.163006
# ephoch #305   loss=0.162841
# ephoch #306   loss=0.162677
# ephoch #307   loss=0.162514
# ephoch #308   loss=0.162352
# ephoch #309   loss=0.162191
# ephoch #310   loss=0.162032
# ephoch #311   loss=0.161873
# ephoch #312   loss=0.161716
# ephoch #313   loss=0.161559
# ephoch #314   loss=0.161404
# ephoch #315   loss=0.161249
# ephoch #316   loss=0.161096
# ephoch #317   loss=0.160943
# ephoch #318   loss=0.160792
# ephoch #319   loss=0.160642
# ephoch #320   loss=0.160492
# ephoch #321   loss=0.160344
# ephoch #322   loss=0.160196
# ephoch #323   loss=0.16005
# ephoch #324   loss=0.159904
# ephoch #325   loss=0.15976
# ephoch #326   loss=0.159616
# ephoch #327   loss=0.159473
# ephoch #328   loss=0.159331
# ephoch #329   loss=0.15919
# ephoch #330   loss=0.15905
# ephoch #331   loss=0.158911
# ephoch #332   loss=0.158773
# ephoch #333   loss=0.158635
# ephoch #334   loss=0.158499
# ephoch #335   loss=0.158363
# ephoch #336   loss=0.158228
# ephoch #337   loss=0.158094
# ephoch #338   loss=0.157961
# ephoch #339   loss=0.157829
# ephoch #340   loss=0.157697
# ephoch #341   loss=0.157566
# ephoch #342   loss=0.157436
# ephoch #343   loss=0.157307
# ephoch #344   loss=0.157179
# ephoch #345   loss=0.157051
# ephoch #346   loss=0.156924
# ephoch #347   loss=0.156798
# ephoch #348   loss=0.156673
# ephoch #349   loss=0.156549
# ephoch #350   loss=0.156425
# ephoch #351   loss=0.156302
# ephoch #352   loss=0.156179
# ephoch #353   loss=0.156058
# ephoch #354   loss=0.155937
# ephoch #355   loss=0.155817
# ephoch #356   loss=0.155698
# ephoch #357   loss=0.155579
# ephoch #358   loss=0.155461
# ephoch #359   loss=0.155344
# ephoch #360   loss=0.155227
# ephoch #361   loss=0.155111
# ephoch #362   loss=0.154996
# ephoch #363   loss=0.154881
# ephoch #364   loss=0.154767
# ephoch #365   loss=0.154654
# ephoch #366   loss=0.154541
# ephoch #367   loss=0.15443
# ephoch #368   loss=0.154318
# ephoch #369   loss=0.154208
# ephoch #370   loss=0.154098
# ephoch #371   loss=0.153988
# ephoch #372   loss=0.153879
# ephoch #373   loss=0.153771
# ephoch #374   loss=0.153664
# ephoch #375   loss=0.153557
# ephoch #376   loss=0.153451
# ephoch #377   loss=0.153345
# ephoch #378   loss=0.15324
# ephoch #379   loss=0.153136
# ephoch #380   loss=0.153032
# ephoch #381   loss=0.152928
# ephoch #382   loss=0.152826
# ephoch #383   loss=0.152723
# ephoch #384   loss=0.152622
# ephoch #385   loss=0.152521
# ephoch #386   loss=0.152421
# ephoch #387   loss=0.152321
# ephoch #388   loss=0.152221
# ephoch #389   loss=0.152123
# ephoch #390   loss=0.152024
# ephoch #391   loss=0.151927
# ephoch #392   loss=0.15183
# ephoch #393   loss=0.151733
# ephoch #394   loss=0.151637
# ephoch #395   loss=0.151541
# ephoch #396   loss=0.151446
# ephoch #397   loss=0.151352
# ephoch #398   loss=0.151258
# ephoch #399   loss=0.151165
# ephoch #400   loss=0.151072
# ephoch #401   loss=0.150979
# ephoch #402   loss=0.150887
# ephoch #403   loss=0.150796
# ephoch #404   loss=0.150705
# ephoch #405   loss=0.150615
# ephoch #406   loss=0.150525
# ephoch #407   loss=0.150435
# ephoch #408   loss=0.150346
# ephoch #409   loss=0.150258
# ephoch #410   loss=0.15017
# ephoch #411   loss=0.150082
# ephoch #412   loss=0.149995
# ephoch #413   loss=0.149909
# ephoch #414   loss=0.149823
# ephoch #415   loss=0.149737
# ephoch #416   loss=0.149652
# ephoch #417   loss=0.149567
# ephoch #418   loss=0.149483
# ephoch #419   loss=0.149399
# ephoch #420   loss=0.149315
# ephoch #421   loss=0.149232
# ephoch #422   loss=0.14915
# ephoch #423   loss=0.149068
# ephoch #424   loss=0.148986
# ephoch #425   loss=0.148905
# ephoch #426   loss=0.148824
# ephoch #427   loss=0.148744
# ephoch #428   loss=0.148664
# ephoch #429   loss=0.148584
# ephoch #430   loss=0.148505
# ephoch #431   loss=0.148427
# ephoch #432   loss=0.148348
# ephoch #433   loss=0.14827
# ephoch #434   loss=0.148193
# ephoch #435   loss=0.148116
# ephoch #436   loss=0.148039
# ephoch #437   loss=0.147963
# ephoch #438   loss=0.147887
# ephoch #439   loss=0.147812
# ephoch #440   loss=0.147737
# ephoch #441   loss=0.147662
# ephoch #442   loss=0.147588
# ephoch #443   loss=0.147514
# ephoch #444   loss=0.14744
# ephoch #445   loss=0.147367
# ephoch #446   loss=0.147294
# ephoch #447   loss=0.147222
# ephoch #448   loss=0.14715
# ephoch #449   loss=0.147078
# ephoch #450   loss=0.147007
# ephoch #451   loss=0.146936
# ephoch #452   loss=0.146865
# ephoch #453   loss=0.146795
# ephoch #454   loss=0.146725
# ephoch #455   loss=0.146656
# ephoch #456   loss=0.146586
# ephoch #457   loss=0.146518
# ephoch #458   loss=0.146449
# ephoch #459   loss=0.146381
# ephoch #460   loss=0.146313
# ephoch #461   loss=0.146246
# ephoch #462   loss=0.146179
# ephoch #463   loss=0.146112
# ephoch #464   loss=0.146046
# ephoch #465   loss=0.14598
# ephoch #466   loss=0.145914
# ephoch #467   loss=0.145848
# ephoch #468   loss=0.145783
# ephoch #469   loss=0.145719
# ephoch #470   loss=0.145654
# ephoch #471   loss=0.14559
# ephoch #472   loss=0.145526
# ephoch #473   loss=0.145463
# ephoch #474   loss=0.1454
# ephoch #475   loss=0.145337
# ephoch #476   loss=0.145274
# ephoch #477   loss=0.145212
# ephoch #478   loss=0.14515
# ephoch #479   loss=0.145088
# ephoch #480   loss=0.145027
# ephoch #481   loss=0.144966
# ephoch #482   loss=0.144905
# ephoch #483   loss=0.144845
# ephoch #484   loss=0.144785
# ephoch #485   loss=0.144725
# ephoch #486   loss=0.144665
# ephoch #487   loss=0.144606
# ephoch #488   loss=0.144547
# ephoch #489   loss=0.144489
# ephoch #490   loss=0.14443
# ephoch #491   loss=0.144372
# ephoch #492   loss=0.144314
# ephoch #493   loss=0.144257
# ephoch #494   loss=0.1442
# ephoch #495   loss=0.144143
# ephoch #496   loss=0.144086
# ephoch #497   loss=0.14403
# ephoch #498   loss=0.143973
# ephoch #499   loss=0.143918
# ephoch #500   loss=0.143862
# ephoch #501   loss=0.143807
# ephoch #502   loss=0.143752
# ephoch #503   loss=0.143697
# ephoch #504   loss=0.143642
# ephoch #505   loss=0.143588
# ephoch #506   loss=0.143534
# ephoch #507   loss=0.14348
# ephoch #508   loss=0.143427
# ephoch #509   loss=0.143373
# ephoch #510   loss=0.14332
# ephoch #511   loss=0.143268
# ephoch #512   loss=0.143215
# ephoch #513   loss=0.143163
# ephoch #514   loss=0.143111
# ephoch #515   loss=0.143059
# ephoch #516   loss=0.143008
# ephoch #517   loss=0.142957
# ephoch #518   loss=0.142906
# ephoch #519   loss=0.142855
# ephoch #520   loss=0.142804
# ephoch #521   loss=0.142754
# ephoch #522   loss=0.142704
# ephoch #523   loss=0.142654
# ephoch #524   loss=0.142605
# ephoch #525   loss=0.142555
# ephoch #526   loss=0.142506
# ephoch #527   loss=0.142457
# ephoch #528   loss=0.142409
# ephoch #529   loss=0.14236
# ephoch #530   loss=0.142312
# ephoch #531   loss=0.142264
# ephoch #532   loss=0.142216
# ephoch #533   loss=0.142169
# ephoch #534   loss=0.142122
# ephoch #535   loss=0.142074
# ephoch #536   loss=0.142028
# ephoch #537   loss=0.141981
# ephoch #538   loss=0.141935
# ephoch #539   loss=0.141888
# ephoch #540   loss=0.141842
# ephoch #541   loss=0.141797
# ephoch #542   loss=0.141751
# ephoch #543   loss=0.141706
# ephoch #544   loss=0.14166
# ephoch #545   loss=0.141615
# ephoch #546   loss=0.141571
# ephoch #547   loss=0.141526
# ephoch #548   loss=0.141482
# ephoch #549   loss=0.141438
# ephoch #550   loss=0.141394
# ephoch #551   loss=0.14135
# ephoch #552   loss=0.141307
# ephoch #553   loss=0.141263
# ephoch #554   loss=0.14122
# ephoch #555   loss=0.141177
# ephoch #556   loss=0.141135
# ephoch #557   loss=0.141092
# ephoch #558   loss=0.14105
# ephoch #559   loss=0.141007
# ephoch #560   loss=0.140966
# ephoch #561   loss=0.140924
# ephoch #562   loss=0.140882
# ephoch #563   loss=0.140841
# ephoch #564   loss=0.1408
# ephoch #565   loss=0.140759
# ephoch #566   loss=0.140718
# ephoch #567   loss=0.140677
# ephoch #568   loss=0.140637
# ephoch #569   loss=0.140596
# ephoch #570   loss=0.140556
# ephoch #571   loss=0.140516
# ephoch #572   loss=0.140477
# ephoch #573   loss=0.140437
# ephoch #574   loss=0.140398
# ephoch #575   loss=0.140358
# ephoch #576   loss=0.140319
# ephoch #577   loss=0.14028
# ephoch #578   loss=0.140242
# ephoch #579   loss=0.140203
# ephoch #580   loss=0.140165
# ephoch #581   loss=0.140127
# ephoch #582   loss=0.140089
# ephoch #583   loss=0.140051
# ephoch #584   loss=0.140013
# ephoch #585   loss=0.139976
# ephoch #586   loss=0.139938
# ephoch #587   loss=0.139901
# ephoch #588   loss=0.139864
# ephoch #589   loss=0.139827
# ephoch #590   loss=0.139791
# ephoch #591   loss=0.139754
# ephoch #592   loss=0.139718
# ephoch #593   loss=0.139682
# ephoch #594   loss=0.139645
# ephoch #595   loss=0.13961
# ephoch #596   loss=0.139574
# ephoch #597   loss=0.139538
# ephoch #598   loss=0.139503
# ephoch #599   loss=0.139468
# ephoch #600   loss=0.139433
# ephoch #601   loss=0.139398
# ephoch #602   loss=0.139363
# ephoch #603   loss=0.139328
# ephoch #604   loss=0.139294
# ephoch #605   loss=0.139259
# ephoch #606   loss=0.139225
# ephoch #607   loss=0.139191
# ephoch #608   loss=0.139157
# ephoch #609   loss=0.139123
# ephoch #610   loss=0.13909
# ephoch #611   loss=0.139056
# ephoch #612   loss=0.139023
# ephoch #613   loss=0.13899
# ephoch #614   loss=0.138957
# ephoch #615   loss=0.138924
# ephoch #616   loss=0.138891
# ephoch #617   loss=0.138858
# ephoch #618   loss=0.138826
# ephoch #619   loss=0.138794
# ephoch #620   loss=0.138761
# ephoch #621   loss=0.138729
# ephoch #622   loss=0.138697
# ephoch #623   loss=0.138666
# ephoch #624   loss=0.138634
# ephoch #625   loss=0.138602
# ephoch #626   loss=0.138571
# ephoch #627   loss=0.13854
# ephoch #628   loss=0.138509
# ephoch #629   loss=0.138478
# ephoch #630   loss=0.138447
# ephoch #631   loss=0.138416
# ephoch #632   loss=0.138385
# ephoch #633   loss=0.138355
# ephoch #634   loss=0.138325
# ephoch #635   loss=0.138294
# ephoch #636   loss=0.138264
# ephoch #637   loss=0.138234
# ephoch #638   loss=0.138204
# ephoch #639   loss=0.138175
# ephoch #640   loss=0.138145
# ephoch #641   loss=0.138116
# ephoch #642   loss=0.138086
# ephoch #643   loss=0.138057
# ephoch #644   loss=0.138028
# ephoch #645   loss=0.137999
# ephoch #646   loss=0.13797
# ephoch #647   loss=0.137942
# ephoch #648   loss=0.137913
# ephoch #649   loss=0.137884
# ephoch #650   loss=0.137856
# ephoch #651   loss=0.137828
# ephoch #652   loss=0.1378
# ephoch #653   loss=0.137772
# ephoch #654   loss=0.137744
# ephoch #655   loss=0.137716
# ephoch #656   loss=0.137688
# ephoch #657   loss=0.137661
# ephoch #658   loss=0.137633
# ephoch #659   loss=0.137606
# ephoch #660   loss=0.137579
# ephoch #661   loss=0.137551
# ephoch #662   loss=0.137524
# ephoch #663   loss=0.137498
# ephoch #664   loss=0.137471
# ephoch #665   loss=0.137444
# ephoch #666   loss=0.137418
# ephoch #667   loss=0.137391
# ephoch #668   loss=0.137365
# ephoch #669   loss=0.137338
# ephoch #670   loss=0.137312
# ephoch #671   loss=0.137286
# ephoch #672   loss=0.13726
# ephoch #673   loss=0.137235
# ephoch #674   loss=0.137209
# ephoch #675   loss=0.137183
# ephoch #676   loss=0.137158
# ephoch #677   loss=0.137132
# ephoch #678   loss=0.137107
# ephoch #679   loss=0.137082
# ephoch #680   loss=0.137057
# ephoch #681   loss=0.137032
# ephoch #682   loss=0.137007
# ephoch #683   loss=0.136982
# ephoch #684   loss=0.136957
# ephoch #685   loss=0.136933
# ephoch #686   loss=0.136908
# ephoch #687   loss=0.136884
# ephoch #688   loss=0.13686
# ephoch #689   loss=0.136835
# ephoch #690   loss=0.136811
# ephoch #691   loss=0.136787
# ephoch #692   loss=0.136763
# ephoch #693   loss=0.136739
# ephoch #694   loss=0.136716
# ephoch #695   loss=0.136692
# ephoch #696   loss=0.136669
# ephoch #697   loss=0.136645
# ephoch #698   loss=0.136622
# ephoch #699   loss=0.136598
# ephoch #700   loss=0.136575
# ephoch #701   loss=0.136552
# ephoch #702   loss=0.136529
# ephoch #703   loss=0.136506
# ephoch #704   loss=0.136483
# ephoch #705   loss=0.136461
# ephoch #706   loss=0.136438
# ephoch #707   loss=0.136416
# ephoch #708   loss=0.136393
# ephoch #709   loss=0.136371
# ephoch #710   loss=0.136348
# ephoch #711   loss=0.136326
# ephoch #712   loss=0.136304
# ephoch #713   loss=0.136282
# ephoch #714   loss=0.13626
# ephoch #715   loss=0.136238
# ephoch #716   loss=0.136217
# ephoch #717   loss=0.136195
# ephoch #718   loss=0.136173
# ephoch #719   loss=0.136152
# ephoch #720   loss=0.13613
# ephoch #721   loss=0.136109
# ephoch #722   loss=0.136088
# ephoch #723   loss=0.136067
# ephoch #724   loss=0.136045
# ephoch #725   loss=0.136024
# ephoch #726   loss=0.136004
# ephoch #727   loss=0.135983
# ephoch #728   loss=0.135962
# ephoch #729   loss=0.135941
# ephoch #730   loss=0.135921
# ephoch #731   loss=0.1359
# ephoch #732   loss=0.13588
# ephoch #733   loss=0.135859
# ephoch #734   loss=0.135839
# ephoch #735   loss=0.135819
# ephoch #736   loss=0.135798
# ephoch #737   loss=0.135778
# ephoch #738   loss=0.135758
# ephoch #739   loss=0.135738
# ephoch #740   loss=0.135719
# ephoch #741   loss=0.135699
# ephoch #742   loss=0.135679
# ephoch #743   loss=0.13566
# ephoch #744   loss=0.13564
# ephoch #745   loss=0.13562
# ephoch #746   loss=0.135601
# ephoch #747   loss=0.135582
# ephoch #748   loss=0.135563
# ephoch #749   loss=0.135543
# ephoch #750   loss=0.135524
# ephoch #751   loss=0.135505
# ephoch #752   loss=0.135486
# ephoch #753   loss=0.135467
# ephoch #754   loss=0.135448
# ephoch #755   loss=0.13543
# ephoch #756   loss=0.135411
# ephoch #757   loss=0.135392
# ephoch #758   loss=0.135374
# ephoch #759   loss=0.135355
# ephoch #760   loss=0.135337
# ephoch #761   loss=0.135319
# ephoch #762   loss=0.1353
# ephoch #763   loss=0.135282
# ephoch #764   loss=0.135264
# ephoch #765   loss=0.135246
# ephoch #766   loss=0.135228
# ephoch #767   loss=0.13521
# ephoch #768   loss=0.135192
# ephoch #769   loss=0.135174
# ephoch #770   loss=0.135157
# ephoch #771   loss=0.135139
# ephoch #772   loss=0.135121
# ephoch #773   loss=0.135104
# ephoch #774   loss=0.135086
# ephoch #775   loss=0.135069
# ephoch #776   loss=0.135051
# ephoch #777   loss=0.135034
# ephoch #778   loss=0.135017
# ephoch #779   loss=0.135
# ephoch #780   loss=0.134983
# ephoch #781   loss=0.134966
# ephoch #782   loss=0.134949
# ephoch #783   loss=0.134932
# ephoch #784   loss=0.134915
# ephoch #785   loss=0.134898
# ephoch #786   loss=0.134881
# ephoch #787   loss=0.134865
# ephoch #788   loss=0.134848
# ephoch #789   loss=0.134832
# ephoch #790   loss=0.134815
# ephoch #791   loss=0.134799
# ephoch #792   loss=0.134782
# ephoch #793   loss=0.134766
# ephoch #794   loss=0.13475
# ephoch #795   loss=0.134733
# ephoch #796   loss=0.134717
# ephoch #797   loss=0.134701
# ephoch #798   loss=0.134685
# ephoch #799   loss=0.134669
# ephoch #800   loss=0.134653
# ephoch #801   loss=0.134638
# ephoch #802   loss=0.134622
# ephoch #803   loss=0.134606
# ephoch #804   loss=0.13459
# ephoch #805   loss=0.134575
# ephoch #806   loss=0.134559
# ephoch #807   loss=0.134544
# ephoch #808   loss=0.134528
# ephoch #809   loss=0.134513
# ephoch #810   loss=0.134497
# ephoch #811   loss=0.134482
# ephoch #812   loss=0.134467
# ephoch #813   loss=0.134452
# ephoch #814   loss=0.134436
# ephoch #815   loss=0.134421
# ephoch #816   loss=0.134406
# ephoch #817   loss=0.134391
# ephoch #818   loss=0.134376
# ephoch #819   loss=0.134362
# ephoch #820   loss=0.134347
# ephoch #821   loss=0.134332
# ephoch #822   loss=0.134317
# ephoch #823   loss=0.134303
# ephoch #824   loss=0.134288
# ephoch #825   loss=0.134273
# ephoch #826   loss=0.134259
# ephoch #827   loss=0.134244
# ephoch #828   loss=0.13423
# ephoch #829   loss=0.134216
# ephoch #830   loss=0.134201
# ephoch #831   loss=0.134187
# ephoch #832   loss=0.134173
# ephoch #833   loss=0.134159
# ephoch #834   loss=0.134145
# ephoch #835   loss=0.134131
# ephoch #836   loss=0.134117
# ephoch #837   loss=0.134103
# ephoch #838   loss=0.134089
# ephoch #839   loss=0.134075
# ephoch #840   loss=0.134061
# ephoch #841   loss=0.134047
# ephoch #842   loss=0.134033
# ephoch #843   loss=0.13402
# ephoch #844   loss=0.134006
# ephoch #845   loss=0.133993
# ephoch #846   loss=0.133979
# ephoch #847   loss=0.133965
# ephoch #848   loss=0.133952
# ephoch #849   loss=0.133939
# ephoch #850   loss=0.133925
# ephoch #851   loss=0.133912
# ephoch #852   loss=0.133899
# ephoch #853   loss=0.133885
# ephoch #854   loss=0.133872
# ephoch #855   loss=0.133859
# ephoch #856   loss=0.133846
# ephoch #857   loss=0.133833
# ephoch #858   loss=0.13382
# ephoch #859   loss=0.133807
# ephoch #860   loss=0.133794
# ephoch #861   loss=0.133781
# ephoch #862   loss=0.133768
# ephoch #863   loss=0.133756
# ephoch #864   loss=0.133743
# ephoch #865   loss=0.13373
# ephoch #866   loss=0.133718
# ephoch #867   loss=0.133705
# ephoch #868   loss=0.133692
# ephoch #869   loss=0.13368
# ephoch #870   loss=0.133667
# ephoch #871   loss=0.133655
# ephoch #872   loss=0.133642
# ephoch #873   loss=0.13363
# ephoch #874   loss=0.133618
# ephoch #875   loss=0.133605
# ephoch #876   loss=0.133593
# ephoch #877   loss=0.133581
# ephoch #878   loss=0.133569
# ephoch #879   loss=0.133557
# ephoch #880   loss=0.133545
# ephoch #881   loss=0.133533
# ephoch #882   loss=0.133521
# ephoch #883   loss=0.133509
# ephoch #884   loss=0.133497
# ephoch #885   loss=0.133485
# ephoch #886   loss=0.133473
# ephoch #887   loss=0.133461
# ephoch #888   loss=0.133449
# ephoch #889   loss=0.133438
# ephoch #890   loss=0.133426
# ephoch #891   loss=0.133414
# ephoch #892   loss=0.133403
# ephoch #893   loss=0.133391
# ephoch #894   loss=0.13338
# ephoch #895   loss=0.133368
# ephoch #896   loss=0.133357
# ephoch #897   loss=0.133345
# ephoch #898   loss=0.133334
# ephoch #899   loss=0.133323
# ephoch #900   loss=0.133311
# ephoch #901   loss=0.1333
# ephoch #902   loss=0.133289
# ephoch #903   loss=0.133277
# ephoch #904   loss=0.133266
# ephoch #905   loss=0.133255
# ephoch #906   loss=0.133244
# ephoch #907   loss=0.133233
# ephoch #908   loss=0.133222
# ephoch #909   loss=0.133211
# ephoch #910   loss=0.1332
# ephoch #911   loss=0.133189
# ephoch #912   loss=0.133178
# ephoch #913   loss=0.133167
# ephoch #914   loss=0.133157
# ephoch #915   loss=0.133146
# ephoch #916   loss=0.133135
# ephoch #917   loss=0.133124
# ephoch #918   loss=0.133114
# ephoch #919   loss=0.133103
# ephoch #920   loss=0.133092
# ephoch #921   loss=0.133082
# ephoch #922   loss=0.133071
# ephoch #923   loss=0.133061
# ephoch #924   loss=0.13305
# ephoch #925   loss=0.13304
# ephoch #926   loss=0.133029
# ephoch #927   loss=0.133019
# ephoch #928   loss=0.133009
# ephoch #929   loss=0.132998
# ephoch #930   loss=0.132988
# ephoch #931   loss=0.132978
# ephoch #932   loss=0.132968
# ephoch #933   loss=0.132957
# ephoch #934   loss=0.132947
# ephoch #935   loss=0.132937
# ephoch #936   loss=0.132927
# ephoch #937   loss=0.132917
# ephoch #938   loss=0.132907
# ephoch #939   loss=0.132897
# ephoch #940   loss=0.132887
# ephoch #941   loss=0.132877
# ephoch #942   loss=0.132867
# ephoch #943   loss=0.132857
# ephoch #944   loss=0.132848
# ephoch #945   loss=0.132838
# ephoch #946   loss=0.132828
# ephoch #947   loss=0.132818
# ephoch #948   loss=0.132808
# ephoch #949   loss=0.132799
# ephoch #950   loss=0.132789
# ephoch #951   loss=0.13278
# ephoch #952   loss=0.13277
# ephoch #953   loss=0.13276
# ephoch #954   loss=0.132751
# ephoch #955   loss=0.132741
# ephoch #956   loss=0.132732
# ephoch #957   loss=0.132722
# ephoch #958   loss=0.132713
# ephoch #959   loss=0.132704
# ephoch #960   loss=0.132694
# ephoch #961   loss=0.132685
# ephoch #962   loss=0.132676
# ephoch #963   loss=0.132666
# ephoch #964   loss=0.132657
# ephoch #965   loss=0.132648
# ephoch #966   loss=0.132639
# ephoch #967   loss=0.132629
# ephoch #968   loss=0.13262
# ephoch #969   loss=0.132611
# ephoch #970   loss=0.132602
# ephoch #971   loss=0.132593
# ephoch #972   loss=0.132584
# ephoch #973   loss=0.132575
# ephoch #974   loss=0.132566
# ephoch #975   loss=0.132557
# ephoch #976   loss=0.132548
# ephoch #977   loss=0.132539
# ephoch #978   loss=0.13253
# ephoch #979   loss=0.132522
# ephoch #980   loss=0.132513
# ephoch #981   loss=0.132504
# ephoch #982   loss=0.132495
# ephoch #983   loss=0.132486
# ephoch #984   loss=0.132478
# ephoch #985   loss=0.132469
# ephoch #986   loss=0.13246
# ephoch #987   loss=0.132452
# ephoch #988   loss=0.132443
# ephoch #989   loss=0.132435
# ephoch #990   loss=0.132426
# ephoch #991   loss=0.132418
# ephoch #992   loss=0.132409
# ephoch #993   loss=0.132401
# ephoch #994   loss=0.132392
# ephoch #995   loss=0.132384
# ephoch #996   loss=0.132375
# ephoch #997   loss=0.132367
# ephoch #998   loss=0.132359
# ephoch #999   loss=0.13235
# ephoch #1000  loss=0.132342
# ephoch #1001  loss=0.132334
# ephoch #1002  loss=0.132325
# ephoch #1003  loss=0.132317
# ephoch #1004  loss=0.132309
# ephoch #1005  loss=0.132301
# ephoch #1006  loss=0.132293
# ephoch #1007  loss=0.132284
# ephoch #1008  loss=0.132276
# ephoch #1009  loss=0.132268
# ephoch #1010  loss=0.13226
# ephoch #1011  loss=0.132252
# ephoch #1012  loss=0.132244
# ephoch #1013  loss=0.132236
# ephoch #1014  loss=0.132228
# ephoch #1015  loss=0.13222
# ephoch #1016  loss=0.132212
# ephoch #1017  loss=0.132204
# ephoch #1018  loss=0.132197
# ephoch #1019  loss=0.132189
# ephoch #1020  loss=0.132181
# ephoch #1021  loss=0.132173
# ephoch #1022  loss=0.132165
# ephoch #1023  loss=0.132157
# ephoch #1024  loss=0.13215
# ephoch #1025  loss=0.132142
# ephoch #1026  loss=0.132134
# ephoch #1027  loss=0.132127
# ephoch #1028  loss=0.132119
# ephoch #1029  loss=0.132111
# ephoch #1030  loss=0.132104
# ephoch #1031  loss=0.132096
# ephoch #1032  loss=0.132089
# ephoch #1033  loss=0.132081
# ephoch #1034  loss=0.132074
# ephoch #1035  loss=0.132066
# ephoch #1036  loss=0.132059
# ephoch #1037  loss=0.132051
# ephoch #1038  loss=0.132044
# ephoch #1039  loss=0.132036
# ephoch #1040  loss=0.132029
# ephoch #1041  loss=0.132021
# ephoch #1042  loss=0.132014
# ephoch #1043  loss=0.132007
# ephoch #1044  loss=0.131999
# ephoch #1045  loss=0.131992
# ephoch #1046  loss=0.131985
# ephoch #1047  loss=0.131978
# ephoch #1048  loss=0.13197
# ephoch #1049  loss=0.131963
# ephoch #1050  loss=0.131956
# ephoch #1051  loss=0.131949
# ephoch #1052  loss=0.131942
# ephoch #1053  loss=0.131935
# ephoch #1054  loss=0.131927
# ephoch #1055  loss=0.13192
# ephoch #1056  loss=0.131913
# ephoch #1057  loss=0.131906
# ephoch #1058  loss=0.131899
# ephoch #1059  loss=0.131892
# ephoch #1060  loss=0.131885
# ephoch #1061  loss=0.131878
# ephoch #1062  loss=0.131871
# ephoch #1063  loss=0.131864
# ephoch #1064  loss=0.131857
# ephoch #1065  loss=0.131851
# ephoch #1066  loss=0.131844
# ephoch #1067  loss=0.131837
# ephoch #1068  loss=0.13183
# ephoch #1069  loss=0.131823
# ephoch #1070  loss=0.131816
# ephoch #1071  loss=0.13181
# ephoch #1072  loss=0.131803
# ephoch #1073  loss=0.131796
# ephoch #1074  loss=0.131789
# ephoch #1075  loss=0.131783
# ephoch #1076  loss=0.131776
# ephoch #1077  loss=0.131769
# ephoch #1078  loss=0.131763
# ephoch #1079  loss=0.131756
# ephoch #1080  loss=0.131749
# ephoch #1081  loss=0.131743
# ephoch #1082  loss=0.131736
# ephoch #1083  loss=0.13173
# ephoch #1084  loss=0.131723
# ephoch #1085  loss=0.131717
# ephoch #1086  loss=0.13171
# ephoch #1087  loss=0.131704
# ephoch #1088  loss=0.131697
# ephoch #1089  loss=0.131691
# ephoch #1090  loss=0.131684
# ephoch #1091  loss=0.131678
# ephoch #1092  loss=0.131671
# ephoch #1093  loss=0.131665
# ephoch #1094  loss=0.131659
# ephoch #1095  loss=0.131652
# ephoch #1096  loss=0.131646
# ephoch #1097  loss=0.13164
# ephoch #1098  loss=0.131633
# ephoch #1099  loss=0.131627
# ephoch #1100  loss=0.131621
# ephoch #1101  loss=0.131615
# ephoch #1102  loss=0.131608
# ephoch #1103  loss=0.131602
# ephoch #1104  loss=0.131596
# ephoch #1105  loss=0.13159
# ephoch #1106  loss=0.131584
# ephoch #1107  loss=0.131577
# ephoch #1108  loss=0.131571
# ephoch #1109  loss=0.131565
# ephoch #1110  loss=0.131559
# ephoch #1111  loss=0.131553
# ephoch #1112  loss=0.131547
# ephoch #1113  loss=0.131541
# ephoch #1114  loss=0.131535
# ephoch #1115  loss=0.131529
# ephoch #1116  loss=0.131523
# ephoch #1117  loss=0.131517
# ephoch #1118  loss=0.131511
# ephoch #1119  loss=0.131505
# ephoch #1120  loss=0.131499
# ephoch #1121  loss=0.131493
# ephoch #1122  loss=0.131487
# ephoch #1123  loss=0.131481
# ephoch #1124  loss=0.131475
# ephoch #1125  loss=0.131469
# ephoch #1126  loss=0.131464
# ephoch #1127  loss=0.131458
# ephoch #1128  loss=0.131452
# ephoch #1129  loss=0.131446
# ephoch #1130  loss=0.13144
# ephoch #1131  loss=0.131435
# ephoch #1132  loss=0.131429
# ephoch #1133  loss=0.131423
# ephoch #1134  loss=0.131417
# ephoch #1135  loss=0.131412
# ephoch #1136  loss=0.131406
# ephoch #1137  loss=0.1314
# ephoch #1138  loss=0.131395
# ephoch #1139  loss=0.131389
# ephoch #1140  loss=0.131383
# ephoch #1141  loss=0.131378
# ephoch #1142  loss=0.131372
# ephoch #1143  loss=0.131367
# ephoch #1144  loss=0.131361
# ephoch #1145  loss=0.131355
# ephoch #1146  loss=0.13135
# ephoch #1147  loss=0.131344
# ephoch #1148  loss=0.131339
# ephoch #1149  loss=0.131333
# ephoch #1150  loss=0.131328
# ephoch #1151  loss=0.131322
# ephoch #1152  loss=0.131317
# ephoch #1153  loss=0.131311
# ephoch #1154  loss=0.131306
# ephoch #1155  loss=0.131301
# ephoch #1156  loss=0.131295
# ephoch #1157  loss=0.13129
# ephoch #1158  loss=0.131284
# ephoch #1159  loss=0.131279
# ephoch #1160  loss=0.131274
# ephoch #1161  loss=0.131268
# ephoch #1162  loss=0.131263
# ephoch #1163  loss=0.131258
# ephoch #1164  loss=0.131252
# ephoch #1165  loss=0.131247
# ephoch #1166  loss=0.131242
# ephoch #1167  loss=0.131237
# ephoch #1168  loss=0.131231
# ephoch #1169  loss=0.131226
# ephoch #1170  loss=0.131221
# ephoch #1171  loss=0.131216
# ephoch #1172  loss=0.13121
# ephoch #1173  loss=0.131205
# ephoch #1174  loss=0.1312
# ephoch #1175  loss=0.131195
# ephoch #1176  loss=0.13119
# ephoch #1177  loss=0.131185
# ephoch #1178  loss=0.13118
# ephoch #1179  loss=0.131174
# ephoch #1180  loss=0.131169
# ephoch #1181  loss=0.131164
# ephoch #1182  loss=0.131159
# ephoch #1183  loss=0.131154
# ephoch #1184  loss=0.131149
# ephoch #1185  loss=0.131144
# ephoch #1186  loss=0.131139
# ephoch #1187  loss=0.131134
# ephoch #1188  loss=0.131129
# ephoch #1189  loss=0.131124
# ephoch #1190  loss=0.131119
# ephoch #1191  loss=0.131114
# ephoch #1192  loss=0.131109
# ephoch #1193  loss=0.131104
# ephoch #1194  loss=0.131099
# ephoch #1195  loss=0.131095
# ephoch #1196  loss=0.13109
# ephoch #1197  loss=0.131085
# ephoch #1198  loss=0.13108
# ephoch #1199  loss=0.131075
# ephoch #1200  loss=0.13107
# ephoch #1201  loss=0.131065
# ephoch #1202  loss=0.131061
# ephoch #1203  loss=0.131056
# ephoch #1204  loss=0.131051
# ephoch #1205  loss=0.131046
# ephoch #1206  loss=0.131041
# ephoch #1207  loss=0.131037
# ephoch #1208  loss=0.131032
# ephoch #1209  loss=0.131027
# ephoch #1210  loss=0.131022
# ephoch #1211  loss=0.131018
# ephoch #1212  loss=0.131013
# ephoch #1213  loss=0.131008
# ephoch #1214  loss=0.131004
# ephoch #1215  loss=0.130999
# ephoch #1216  loss=0.130994
# ephoch #1217  loss=0.13099
# ephoch #1218  loss=0.130985
# ephoch #1219  loss=0.13098
# ephoch #1220  loss=0.130976
# ephoch #1221  loss=0.130971
# ephoch #1222  loss=0.130967
# ephoch #1223  loss=0.130962
# ephoch #1224  loss=0.130957
# ephoch #1225  loss=0.130953
# ephoch #1226  loss=0.130948
# ephoch #1227  loss=0.130944
# ephoch #1228  loss=0.130939
# ephoch #1229  loss=0.130935
# ephoch #1230  loss=0.13093
# ephoch #1231  loss=0.130926
# ephoch #1232  loss=0.130921
# ephoch #1233  loss=0.130917
# ephoch #1234  loss=0.130912
# ephoch #1235  loss=0.130908
# ephoch #1236  loss=0.130903
# ephoch #1237  loss=0.130899
# ephoch #1238  loss=0.130895
# ephoch #1239  loss=0.13089
# ephoch #1240  loss=0.130886
# ephoch #1241  loss=0.130881
# ephoch #1242  loss=0.130877
# ephoch #1243  loss=0.130873
# ephoch #1244  loss=0.130868
# ephoch #1245  loss=0.130864
# ephoch #1246  loss=0.13086
# ephoch #1247  loss=0.130855
# ephoch #1248  loss=0.130851
# ephoch #1249  loss=0.130847
# ephoch #1250  loss=0.130842
# ephoch #1251  loss=0.130838
# ephoch #1252  loss=0.130834
# ephoch #1253  loss=0.13083
# ephoch #1254  loss=0.130825
# ephoch #1255  loss=0.130821
# ephoch #1256  loss=0.130817
# ephoch #1257  loss=0.130813
# ephoch #1258  loss=0.130808
# ephoch #1259  loss=0.130804
# ephoch #1260  loss=0.1308
# ephoch #1261  loss=0.130796
# ephoch #1262  loss=0.130792
# ephoch #1263  loss=0.130788
# ephoch #1264  loss=0.130783
# ephoch #1265  loss=0.130779
# ephoch #1266  loss=0.130775
# ephoch #1267  loss=0.130771
# ephoch #1268  loss=0.130767
# ephoch #1269  loss=0.130763
# ephoch #1270  loss=0.130759
# ephoch #1271  loss=0.130755
# ephoch #1272  loss=0.13075
# ephoch #1273  loss=0.130746
# ephoch #1274  loss=0.130742
# ephoch #1275  loss=0.130738
# ephoch #1276  loss=0.130734
# ephoch #1277  loss=0.13073
# ephoch #1278  loss=0.130726
# ephoch #1279  loss=0.130722
# ephoch #1280  loss=0.130718
# ephoch #1281  loss=0.130714
# ephoch #1282  loss=0.13071
# ephoch #1283  loss=0.130706
# ephoch #1284  loss=0.130702
# ephoch #1285  loss=0.130698
# ephoch #1286  loss=0.130694
# ephoch #1287  loss=0.13069
# ephoch #1288  loss=0.130686
# ephoch #1289  loss=0.130683
# ephoch #1290  loss=0.130679
# ephoch #1291  loss=0.130675
# ephoch #1292  loss=0.130671
# ephoch #1293  loss=0.130667
# ephoch #1294  loss=0.130663
# ephoch #1295  loss=0.130659
# ephoch #1296  loss=0.130655
# ephoch #1297  loss=0.130652
# ephoch #1298  loss=0.130648
# ephoch #1299  loss=0.130644
# ephoch #1300  loss=0.13064
# ephoch #1301  loss=0.130636
# ephoch #1302  loss=0.130632
# ephoch #1303  loss=0.130629
# ephoch #1304  loss=0.130625
# ephoch #1305  loss=0.130621
# ephoch #1306  loss=0.130617
# ephoch #1307  loss=0.130613
# ephoch #1308  loss=0.13061
# ephoch #1309  loss=0.130606
# ephoch #1310  loss=0.130602
# ephoch #1311  loss=0.130599
# ephoch #1312  loss=0.130595
# ephoch #1313  loss=0.130591
# ephoch #1314  loss=0.130587
# ephoch #1315  loss=0.130584
# ephoch #1316  loss=0.13058
# ephoch #1317  loss=0.130576
# ephoch #1318  loss=0.130573
# ephoch #1319  loss=0.130569
# ephoch #1320  loss=0.130565
# ephoch #1321  loss=0.130562
# ephoch #1322  loss=0.130558
# ephoch #1323  loss=0.130554
# ephoch #1324  loss=0.130551
# ephoch #1325  loss=0.130547
# ephoch #1326  loss=0.130544
# ephoch #1327  loss=0.13054
# ephoch #1328  loss=0.130536
# ephoch #1329  loss=0.130533
# ephoch #1330  loss=0.130529
# ephoch #1331  loss=0.130526
# ephoch #1332  loss=0.130522
# ephoch #1333  loss=0.130519
# ephoch #1334  loss=0.130515
# ephoch #1335  loss=0.130511
# ephoch #1336  loss=0.130508
# ephoch #1337  loss=0.130504
# ephoch #1338  loss=0.130501
# ephoch #1339  loss=0.130497
# ephoch #1340  loss=0.130494
# ephoch #1341  loss=0.13049
# ephoch #1342  loss=0.130487
# ephoch #1343  loss=0.130483
# ephoch #1344  loss=0.13048
# ephoch #1345  loss=0.130476
# ephoch #1346  loss=0.130473
# ephoch #1347  loss=0.13047
# ephoch #1348  loss=0.130466
# ephoch #1349  loss=0.130463
# ephoch #1350  loss=0.130459
# ephoch #1351  loss=0.130456
# ephoch #1352  loss=0.130452
# ephoch #1353  loss=0.130449
# ephoch #1354  loss=0.130446
# ephoch #1355  loss=0.130442
# ephoch #1356  loss=0.130439
# ephoch #1357  loss=0.130436
# ephoch #1358  loss=0.130432
# ephoch #1359  loss=0.130429
# ephoch #1360  loss=0.130425
# ephoch #1361  loss=0.130422
# ephoch #1362  loss=0.130419
# ephoch #1363  loss=0.130415
# ephoch #1364  loss=0.130412
# ephoch #1365  loss=0.130409
# ephoch #1366  loss=0.130406
# ephoch #1367  loss=0.130402
# ephoch #1368  loss=0.130399
# ephoch #1369  loss=0.130396
# ephoch #1370  loss=0.130392
# ephoch #1371  loss=0.130389
# ephoch #1372  loss=0.130386
# ephoch #1373  loss=0.130383
# ephoch #1374  loss=0.130379
# ephoch #1375  loss=0.130376
# ephoch #1376  loss=0.130373
# ephoch #1377  loss=0.13037
# ephoch #1378  loss=0.130366
# ephoch #1379  loss=0.130363
# ephoch #1380  loss=0.13036
# ephoch #1381  loss=0.130357
# ephoch #1382  loss=0.130354
# ephoch #1383  loss=0.13035
# ephoch #1384  loss=0.130347
# ephoch #1385  loss=0.130344
# ephoch #1386  loss=0.130341
# ephoch #1387  loss=0.130338
# ephoch #1388  loss=0.130335
# ephoch #1389  loss=0.130331
# ephoch #1390  loss=0.130328
# ephoch #1391  loss=0.130325
# ephoch #1392  loss=0.130322
# ephoch #1393  loss=0.130319
# ephoch #1394  loss=0.130316
# ephoch #1395  loss=0.130313
# ephoch #1396  loss=0.13031
# ephoch #1397  loss=0.130306
# ephoch #1398  loss=0.130303
# ephoch #1399  loss=0.1303
# ephoch #1400  loss=0.130297
# ephoch #1401  loss=0.130294
# ephoch #1402  loss=0.130291
# ephoch #1403  loss=0.130288
# ephoch #1404  loss=0.130285
# ephoch #1405  loss=0.130282
# ephoch #1406  loss=0.130279
# ephoch #1407  loss=0.130276
# ephoch #1408  loss=0.130273
# ephoch #1409  loss=0.13027
# ephoch #1410  loss=0.130267
# ephoch #1411  loss=0.130264
# ephoch #1412  loss=0.130261
# ephoch #1413  loss=0.130258
# ephoch #1414  loss=0.130255
# ephoch #1415  loss=0.130252
# ephoch #1416  loss=0.130249
# ephoch #1417  loss=0.130246
# ephoch #1418  loss=0.130243
# ephoch #1419  loss=0.13024
# ephoch #1420  loss=0.130237
# ephoch #1421  loss=0.130234
# ephoch #1422  loss=0.130231
# ephoch #1423  loss=0.130228
# ephoch #1424  loss=0.130225
# ephoch #1425  loss=0.130222
# ephoch #1426  loss=0.130219
# ephoch #1427  loss=0.130217
# ephoch #1428  loss=0.130214
# ephoch #1429  loss=0.130211
# ephoch #1430  loss=0.130208
# ephoch #1431  loss=0.130205
# ephoch #1432  loss=0.130202
# ephoch #1433  loss=0.130199
# ephoch #1434  loss=0.130196
# ephoch #1435  loss=0.130194
# ephoch #1436  loss=0.130191
# ephoch #1437  loss=0.130188
# ephoch #1438  loss=0.130185
# ephoch #1439  loss=0.130182
# ephoch #1440  loss=0.130179
# ephoch #1441  loss=0.130176
# ephoch #1442  loss=0.130174
# ephoch #1443  loss=0.130171
# ephoch #1444  loss=0.130168
# ephoch #1445  loss=0.130165
# ephoch #1446  loss=0.130162
# ephoch #1447  loss=0.13016
# ephoch #1448  loss=0.130157
# ephoch #1449  loss=0.130154
# ephoch #1450  loss=0.130151
# ephoch #1451  loss=0.130149
# ephoch #1452  loss=0.130146
# ephoch #1453  loss=0.130143
# ephoch #1454  loss=0.13014
# ephoch #1455  loss=0.130138
# ephoch #1456  loss=0.130135
# ephoch #1457  loss=0.130132
# ephoch #1458  loss=0.130129
# ephoch #1459  loss=0.130127
# ephoch #1460  loss=0.130124
# ephoch #1461  loss=0.130121
# ephoch #1462  loss=0.130118
# ephoch #1463  loss=0.130116
# ephoch #1464  loss=0.130113
# ephoch #1465  loss=0.13011
# ephoch #1466  loss=0.130108
# ephoch #1467  loss=0.130105
# ephoch #1468  loss=0.130102
# ephoch #1469  loss=0.1301
# ephoch #1470  loss=0.130097
# ephoch #1471  loss=0.130094
# ephoch #1472  loss=0.130092
# ephoch #1473  loss=0.130089
# ephoch #1474  loss=0.130086
# ephoch #1475  loss=0.130084
# ephoch #1476  loss=0.130081
# ephoch #1477  loss=0.130078
# ephoch #1478  loss=0.130076
# ephoch #1479  loss=0.130073
# ephoch #1480  loss=0.130071
# ephoch #1481  loss=0.130068
# ephoch #1482  loss=0.130065
# ephoch #1483  loss=0.130063
# ephoch #1484  loss=0.13006
# ephoch #1485  loss=0.130058
# ephoch #1486  loss=0.130055
# ephoch #1487  loss=0.130052
# ephoch #1488  loss=0.13005
# ephoch #1489  loss=0.130047
# ephoch #1490  loss=0.130045
# ephoch #1491  loss=0.130042
# ephoch #1492  loss=0.13004
# ephoch #1493  loss=0.130037
# ephoch #1494  loss=0.130035
# ephoch #1495  loss=0.130032
# ephoch #1496  loss=0.130029
# ephoch #1497  loss=0.130027
# ephoch #1498  loss=0.130024
# ephoch #1499  loss=0.130022
# ephoch #1500  loss=0.130019
# ephoch #1501  loss=0.130017
# ephoch #1502  loss=0.130014
# ephoch #1503  loss=0.130012
# ephoch #1504  loss=0.130009
# ephoch #1505  loss=0.130007
# ephoch #1506  loss=0.130004
# ephoch #1507  loss=0.130002
# ephoch #1508  loss=0.129999
# ephoch #1509  loss=0.129997
# ephoch #1510  loss=0.129995
# ephoch #1511  loss=0.129992
# ephoch #1512  loss=0.12999
# ephoch #1513  loss=0.129987
# ephoch #1514  loss=0.129985
# ephoch #1515  loss=0.129982
# ephoch #1516  loss=0.12998
# ephoch #1517  loss=0.129977
# ephoch #1518  loss=0.129975
# ephoch #1519  loss=0.129973
# ephoch #1520  loss=0.12997
# ephoch #1521  loss=0.129968
# ephoch #1522  loss=0.129965
# ephoch #1523  loss=0.129963
# ephoch #1524  loss=0.129961
# ephoch #1525  loss=0.129958
# ephoch #1526  loss=0.129956
# ephoch #1527  loss=0.129953
# ephoch #1528  loss=0.129951
# ephoch #1529  loss=0.129949
# ephoch #1530  loss=0.129946
# ephoch #1531  loss=0.129944
# ephoch #1532  loss=0.129941
# ephoch #1533  loss=0.129939
# ephoch #1534  loss=0.129937
# ephoch #1535  loss=0.129934
# ephoch #1536  loss=0.129932
# ephoch #1537  loss=0.12993
# ephoch #1538  loss=0.129927
# ephoch #1539  loss=0.129925
# ephoch #1540  loss=0.129923
# ephoch #1541  loss=0.12992
# ephoch #1542  loss=0.129918
# ephoch #1543  loss=0.129916
# ephoch #1544  loss=0.129913
# ephoch #1545  loss=0.129911
# ephoch #1546  loss=0.129909
# ephoch #1547  loss=0.129907
# ephoch #1548  loss=0.129904
# ephoch #1549  loss=0.129902
# ephoch #1550  loss=0.1299
# ephoch #1551  loss=0.129897
# ephoch #1552  loss=0.129895
# ephoch #1553  loss=0.129893
# ephoch #1554  loss=0.129891
# ephoch #1555  loss=0.129888
# ephoch #1556  loss=0.129886
# ephoch #1557  loss=0.129884
# ephoch #1558  loss=0.129882
# ephoch #1559  loss=0.129879
# ephoch #1560  loss=0.129877
# ephoch #1561  loss=0.129875
# ephoch #1562  loss=0.129873
# ephoch #1563  loss=0.12987
# ephoch #1564  loss=0.129868
# ephoch #1565  loss=0.129866
# ephoch #1566  loss=0.129864
# ephoch #1567  loss=0.129862
# ephoch #1568  loss=0.129859
# ephoch #1569  loss=0.129857
# ephoch #1570  loss=0.129855
# ephoch #1571  loss=0.129853
# ephoch #1572  loss=0.129851
# ephoch #1573  loss=0.129848
# ephoch #1574  loss=0.129846
# ephoch #1575  loss=0.129844
# ephoch #1576  loss=0.129842
# ephoch #1577  loss=0.12984
# ephoch #1578  loss=0.129837
# ephoch #1579  loss=0.129835
# ephoch #1580  loss=0.129833
# ephoch #1581  loss=0.129831
# ephoch #1582  loss=0.129829
# ephoch #1583  loss=0.129827
# ephoch #1584  loss=0.129825
# ephoch #1585  loss=0.129822
# ephoch #1586  loss=0.12982
# ephoch #1587  loss=0.129818
# ephoch #1588  loss=0.129816
# ephoch #1589  loss=0.129814
# ephoch #1590  loss=0.129812
# ephoch #1591  loss=0.12981
# ephoch #1592  loss=0.129808
# ephoch #1593  loss=0.129805
# ephoch #1594  loss=0.129803
# ephoch #1595  loss=0.129801
# ephoch #1596  loss=0.129799
# ephoch #1597  loss=0.129797
# ephoch #1598  loss=0.129795
# ephoch #1599  loss=0.129793
# ephoch #1600  loss=0.129791
# ephoch #1601  loss=0.129789
# ephoch #1602  loss=0.129787
# ephoch #1603  loss=0.129785
# ephoch #1604  loss=0.129782
# ephoch #1605  loss=0.12978
# ephoch #1606  loss=0.129778
# ephoch #1607  loss=0.129776
# ephoch #1608  loss=0.129774
# ephoch #1609  loss=0.129772
# ephoch #1610  loss=0.12977
# ephoch #1611  loss=0.129768
# ephoch #1612  loss=0.129766
# ephoch #1613  loss=0.129764
# ephoch #1614  loss=0.129762
# ephoch #1615  loss=0.12976
# ephoch #1616  loss=0.129758
# ephoch #1617  loss=0.129756
# ephoch #1618  loss=0.129754
# ephoch #1619  loss=0.129752
# ephoch #1620  loss=0.12975
# ephoch #1621  loss=0.129748
# ephoch #1622  loss=0.129746
# ephoch #1623  loss=0.129744
# ephoch #1624  loss=0.129742
# ephoch #1625  loss=0.12974
# ephoch #1626  loss=0.129738
# ephoch #1627  loss=0.129736
# ephoch #1628  loss=0.129734
# ephoch #1629  loss=0.129732
# ephoch #1630  loss=0.12973
# ephoch #1631  loss=0.129728
# ephoch #1632  loss=0.129726
# ephoch #1633  loss=0.129724
# ephoch #1634  loss=0.129722
# ephoch #1635  loss=0.12972
# ephoch #1636  loss=0.129718
# ephoch #1637  loss=0.129716
# ephoch #1638  loss=0.129714
# ephoch #1639  loss=0.129712
# ephoch #1640  loss=0.12971
# ephoch #1641  loss=0.129709
# ephoch #1642  loss=0.129707
# ephoch #1643  loss=0.129705
# ephoch #1644  loss=0.129703
# ephoch #1645  loss=0.129701
# ephoch #1646  loss=0.129699
# ephoch #1647  loss=0.129697
# ephoch #1648  loss=0.129695
# ephoch #1649  loss=0.129693
# ephoch #1650  loss=0.129691
# ephoch #1651  loss=0.129689
# ephoch #1652  loss=0.129687
# ephoch #1653  loss=0.129686
# ephoch #1654  loss=0.129684
# ephoch #1655  loss=0.129682
# ephoch #1656  loss=0.12968
# ephoch #1657  loss=0.129678
# ephoch #1658  loss=0.129676
# ephoch #1659  loss=0.129674
# ephoch #1660  loss=0.129672
# ephoch #1661  loss=0.129671
# ephoch #1662  loss=0.129669
# ephoch #1663  loss=0.129667
# ephoch #1664  loss=0.129665
# ephoch #1665  loss=0.129663
# ephoch #1666  loss=0.129661
# ephoch #1667  loss=0.129659
# ephoch #1668  loss=0.129658
# ephoch #1669  loss=0.129656
# ephoch #1670  loss=0.129654
# ephoch #1671  loss=0.129652
# ephoch #1672  loss=0.12965
# ephoch #1673  loss=0.129648
# ephoch #1674  loss=0.129647
# ephoch #1675  loss=0.129645
# ephoch #1676  loss=0.129643
# ephoch #1677  loss=0.129641
# ephoch #1678  loss=0.129639
# ephoch #1679  loss=0.129637
# ephoch #1680  loss=0.129636
# ephoch #1681  loss=0.129634
# ephoch #1682  loss=0.129632
# ephoch #1683  loss=0.12963
# ephoch #1684  loss=0.129628
# ephoch #1685  loss=0.129627
# ephoch #1686  loss=0.129625
# ephoch #1687  loss=0.129623
# ephoch #1688  loss=0.129621
# ephoch #1689  loss=0.12962
# ephoch #1690  loss=0.129618
# ephoch #1691  loss=0.129616
# ephoch #1692  loss=0.129614
# ephoch #1693  loss=0.129612
# ephoch #1694  loss=0.129611
# ephoch #1695  loss=0.129609
# ephoch #1696  loss=0.129607
# ephoch #1697  loss=0.129605
# ephoch #1698  loss=0.129604
# ephoch #1699  loss=0.129602
# ephoch #1700  loss=0.1296
# ephoch #1701  loss=0.129598
# ephoch #1702  loss=0.129597
# ephoch #1703  loss=0.129595
# ephoch #1704  loss=0.129593
# ephoch #1705  loss=0.129591
# ephoch #1706  loss=0.12959
# ephoch #1707  loss=0.129588
# ephoch #1708  loss=0.129586
# ephoch #1709  loss=0.129585
# ephoch #1710  loss=0.129583
# ephoch #1711  loss=0.129581
# ephoch #1712  loss=0.129579
# ephoch #1713  loss=0.129578
# ephoch #1714  loss=0.129576
# ephoch #1715  loss=0.129574
# ephoch #1716  loss=0.129573
# ephoch #1717  loss=0.129571
# ephoch #1718  loss=0.129569
# ephoch #1719  loss=0.129568
# ephoch #1720  loss=0.129566
# ephoch #1721  loss=0.129564
# ephoch #1722  loss=0.129562
# ephoch #1723  loss=0.129561
# ephoch #1724  loss=0.129559
# ephoch #1725  loss=0.129557
# ephoch #1726  loss=0.129556
# ephoch #1727  loss=0.129554
# ephoch #1728  loss=0.129552
# ephoch #1729  loss=0.129551
# ephoch #1730  loss=0.129549
# ephoch #1731  loss=0.129547
# ephoch #1732  loss=0.129546
# ephoch #1733  loss=0.129544
# ephoch #1734  loss=0.129543
# ephoch #1735  loss=0.129541
# ephoch #1736  loss=0.129539
# ephoch #1737  loss=0.129538
# ephoch #1738  loss=0.129536
# ephoch #1739  loss=0.129534
# ephoch #1740  loss=0.129533
# ephoch #1741  loss=0.129531
# ephoch #1742  loss=0.129529
# ephoch #1743  loss=0.129528
# ephoch #1744  loss=0.129526
# ephoch #1745  loss=0.129525
# ephoch #1746  loss=0.129523
# ephoch #1747  loss=0.129521
# ephoch #1748  loss=0.12952
# ephoch #1749  loss=0.129518
# ephoch #1750  loss=0.129517
# ephoch #1751  loss=0.129515
# ephoch #1752  loss=0.129513
# ephoch #1753  loss=0.129512
# ephoch #1754  loss=0.12951
# ephoch #1755  loss=0.129509
# ephoch #1756  loss=0.129507
# ephoch #1757  loss=0.129505
# ephoch #1758  loss=0.129504
# ephoch #1759  loss=0.129502
# ephoch #1760  loss=0.129501
# ephoch #1761  loss=0.129499
# ephoch #1762  loss=0.129497
# ephoch #1763  loss=0.129496
# ephoch #1764  loss=0.129494
# ephoch #1765  loss=0.129493
# ephoch #1766  loss=0.129491
# ephoch #1767  loss=0.12949
# ephoch #1768  loss=0.129488
# ephoch #1769  loss=0.129487
# ephoch #1770  loss=0.129485
# ephoch #1771  loss=0.129483
# ephoch #1772  loss=0.129482
# ephoch #1773  loss=0.12948
# ephoch #1774  loss=0.129479
# ephoch #1775  loss=0.129477
# ephoch #1776  loss=0.129476
# ephoch #1777  loss=0.129474
# ephoch #1778  loss=0.129473
# ephoch #1779  loss=0.129471
# ephoch #1780  loss=0.12947
# ephoch #1781  loss=0.129468
# ephoch #1782  loss=0.129467
# ephoch #1783  loss=0.129465
# ephoch #1784  loss=0.129463
# ephoch #1785  loss=0.129462
# ephoch #1786  loss=0.12946
# ephoch #1787  loss=0.129459
# ephoch #1788  loss=0.129457
# ephoch #1789  loss=0.129456
# ephoch #1790  loss=0.129454
# ephoch #1791  loss=0.129453
# ephoch #1792  loss=0.129451
# ephoch #1793  loss=0.12945
# ephoch #1794  loss=0.129448
# ephoch #1795  loss=0.129447
# ephoch #1796  loss=0.129445
# ephoch #1797  loss=0.129444
# ephoch #1798  loss=0.129443
# ephoch #1799  loss=0.129441
# ephoch #1800  loss=0.12944
# ephoch #1801  loss=0.129438
# ephoch #1802  loss=0.129437
# ephoch #1803  loss=0.129435
# ephoch #1804  loss=0.129434
# ephoch #1805  loss=0.129432
# ephoch #1806  loss=0.129431
# ephoch #1807  loss=0.129429
# ephoch #1808  loss=0.129428
# ephoch #1809  loss=0.129426
# ephoch #1810  loss=0.129425
# ephoch #1811  loss=0.129423
# ephoch #1812  loss=0.129422
# ephoch #1813  loss=0.129421
# ephoch #1814  loss=0.129419
# ephoch #1815  loss=0.129418
# ephoch #1816  loss=0.129416
# ephoch #1817  loss=0.129415
# ephoch #1818  loss=0.129413
# ephoch #1819  loss=0.129412
# ephoch #1820  loss=0.12941
# ephoch #1821  loss=0.129409
# ephoch #1822  loss=0.129408
# ephoch #1823  loss=0.129406
# ephoch #1824  loss=0.129405
# ephoch #1825  loss=0.129403
# ephoch #1826  loss=0.129402
# ephoch #1827  loss=0.1294
# ephoch #1828  loss=0.129399
# ephoch #1829  loss=0.129398
# ephoch #1830  loss=0.129396
# ephoch #1831  loss=0.129395
# ephoch #1832  loss=0.129393
# ephoch #1833  loss=0.129392
# ephoch #1834  loss=0.129391
# ephoch #1835  loss=0.129389
# ephoch #1836  loss=0.129388
# ephoch #1837  loss=0.129386
# ephoch #1838  loss=0.129385
# ephoch #1839  loss=0.129384
# ephoch #1840  loss=0.129382
# ephoch #1841  loss=0.129381
# ephoch #1842  loss=0.12938
# ephoch #1843  loss=0.129378
# ephoch #1844  loss=0.129377
# ephoch #1845  loss=0.129375
# ephoch #1846  loss=0.129374
# ephoch #1847  loss=0.129373
# ephoch #1848  loss=0.129371
# ephoch #1849  loss=0.12937
# ephoch #1850  loss=0.129369
# ephoch #1851  loss=0.129367
# ephoch #1852  loss=0.129366
# ephoch #1853  loss=0.129364
# ephoch #1854  loss=0.129363
# ephoch #1855  loss=0.129362
# ephoch #1856  loss=0.12936
# ephoch #1857  loss=0.129359
# ephoch #1858  loss=0.129358
# ephoch #1859  loss=0.129356
# ephoch #1860  loss=0.129355
# ephoch #1861  loss=0.129354
# ephoch #1862  loss=0.129352
# ephoch #1863  loss=0.129351
# ephoch #1864  loss=0.12935
# ephoch #1865  loss=0.129348
# ephoch #1866  loss=0.129347
# ephoch #1867  loss=0.129346
# ephoch #1868  loss=0.129344
# ephoch #1869  loss=0.129343
# ephoch #1870  loss=0.129342
# ephoch #1871  loss=0.12934
# ephoch #1872  loss=0.129339
# ephoch #1873  loss=0.129338
# ephoch #1874  loss=0.129336
# ephoch #1875  loss=0.129335
# ephoch #1876  loss=0.129334
# ephoch #1877  loss=0.129332
# ephoch #1878  loss=0.129331
# ephoch #1879  loss=0.12933
# ephoch #1880  loss=0.129329
# ephoch #1881  loss=0.129327
# ephoch #1882  loss=0.129326
# ephoch #1883  loss=0.129325
# ephoch #1884  loss=0.129323
# ephoch #1885  loss=0.129322
# ephoch #1886  loss=0.129321
# ephoch #1887  loss=0.129319
# ephoch #1888  loss=0.129318
# ephoch #1889  loss=0.129317
# ephoch #1890  loss=0.129316
# ephoch #1891  loss=0.129314
# ephoch #1892  loss=0.129313
# ephoch #1893  loss=0.129312
# ephoch #1894  loss=0.12931
# ephoch #1895  loss=0.129309
# ephoch #1896  loss=0.129308
# ephoch #1897  loss=0.129307
# ephoch #1898  loss=0.129305
# ephoch #1899  loss=0.129304
# ephoch #1900  loss=0.129303
# ephoch #1901  loss=0.129302
# ephoch #1902  loss=0.1293
# ephoch #1903  loss=0.129299
# ephoch #1904  loss=0.129298
# ephoch #1905  loss=0.129297
# ephoch #1906  loss=0.129295
# ephoch #1907  loss=0.129294
# ephoch #1908  loss=0.129293
# ephoch #1909  loss=0.129292
# ephoch #1910  loss=0.12929
# ephoch #1911  loss=0.129289
# ephoch #1912  loss=0.129288
# ephoch #1913  loss=0.129287
# ephoch #1914  loss=0.129285
# ephoch #1915  loss=0.129284
# ephoch #1916  loss=0.129283
# ephoch #1917  loss=0.129282
# ephoch #1918  loss=0.12928
# ephoch #1919  loss=0.129279
# ephoch #1920  loss=0.129278
# ephoch #1921  loss=0.129277
# ephoch #1922  loss=0.129276
# ephoch #1923  loss=0.129274
# ephoch #1924  loss=0.129273
# ephoch #1925  loss=0.129272
# ephoch #1926  loss=0.129271
# ephoch #1927  loss=0.129269
# ephoch #1928  loss=0.129268
# ephoch #1929  loss=0.129267
# ephoch #1930  loss=0.129266
# ephoch #1931  loss=0.129265
# ephoch #1932  loss=0.129263
# ephoch #1933  loss=0.129262
# ephoch #1934  loss=0.129261
# ephoch #1935  loss=0.12926
# ephoch #1936  loss=0.129259
# ephoch #1937  loss=0.129257
# ephoch #1938  loss=0.129256
# ephoch #1939  loss=0.129255
# ephoch #1940  loss=0.129254
# ephoch #1941  loss=0.129253
# ephoch #1942  loss=0.129252
# ephoch #1943  loss=0.12925
# ephoch #1944  loss=0.129249
# ephoch #1945  loss=0.129248
# ephoch #1946  loss=0.129247
# ephoch #1947  loss=0.129246
# ephoch #1948  loss=0.129244
# ephoch #1949  loss=0.129243
# ephoch #1950  loss=0.129242
# ephoch #1951  loss=0.129241
# ephoch #1952  loss=0.12924
# ephoch #1953  loss=0.129239
# ephoch #1954  loss=0.129237
# ephoch #1955  loss=0.129236
# ephoch #1956  loss=0.129235
# ephoch #1957  loss=0.129234
# ephoch #1958  loss=0.129233
# ephoch #1959  loss=0.129232
# ephoch #1960  loss=0.12923
# ephoch #1961  loss=0.129229
# ephoch #1962  loss=0.129228
# ephoch #1963  loss=0.129227
# ephoch #1964  loss=0.129226
# ephoch #1965  loss=0.129225
# ephoch #1966  loss=0.129224
# ephoch #1967  loss=0.129222
# ephoch #1968  loss=0.129221
# ephoch #1969  loss=0.12922
# ephoch #1970  loss=0.129219
# ephoch #1971  loss=0.129218
# ephoch #1972  loss=0.129217
# ephoch #1973  loss=0.129216
# ephoch #1974  loss=0.129214
# ephoch #1975  loss=0.129213
# ephoch #1976  loss=0.129212
# ephoch #1977  loss=0.129211
# ephoch #1978  loss=0.12921
# ephoch #1979  loss=0.129209
# ephoch #1980  loss=0.129208
# ephoch #1981  loss=0.129207
# ephoch #1982  loss=0.129205
# ephoch #1983  loss=0.129204
# ephoch #1984  loss=0.129203
# ephoch #1985  loss=0.129202
# ephoch #1986  loss=0.129201
# ephoch #1987  loss=0.1292
# ephoch #1988  loss=0.129199
# ephoch #1989  loss=0.129198
# ephoch #1990  loss=0.129197
# ephoch #1991  loss=0.129196
# ephoch #1992  loss=0.129194
# ephoch #1993  loss=0.129193
# ephoch #1994  loss=0.129192
# ephoch #1995  loss=0.129191
# ephoch #1996  loss=0.12919
# ephoch #1997  loss=0.129189
# ephoch #1998  loss=0.129188
# ephoch #1999  loss=0.129187
# ephoch #2000  loss=0.129186
# ephoch #2001  loss=0.129185
# ephoch #2002  loss=0.129183
# ephoch #2003  loss=0.129182
# ephoch #2004  loss=0.129181
# ephoch #2005  loss=0.12918
# ephoch #2006  loss=0.129179
# ephoch #2007  loss=0.129178
# ephoch #2008  loss=0.129177
# ephoch #2009  loss=0.129176
# ephoch #2010  loss=0.129175
# ephoch #2011  loss=0.129174
# ephoch #2012  loss=0.129173
# ephoch #2013  loss=0.129172
# ephoch #2014  loss=0.129171
# ephoch #2015  loss=0.12917
# ephoch #2016  loss=0.129168
# ephoch #2017  loss=0.129167
# ephoch #2018  loss=0.129166
# ephoch #2019  loss=0.129165
# ephoch #2020  loss=0.129164
# ephoch #2021  loss=0.129163
# ephoch #2022  loss=0.129162
# ephoch #2023  loss=0.129161
# ephoch #2024  loss=0.12916
# ephoch #2025  loss=0.129159
# ephoch #2026  loss=0.129158
# ephoch #2027  loss=0.129157
# ephoch #2028  loss=0.129156
# ephoch #2029  loss=0.129155
# ephoch #2030  loss=0.129154
# ephoch #2031  loss=0.129153
# ephoch #2032  loss=0.129152
# ephoch #2033  loss=0.129151
# ephoch #2034  loss=0.12915
# ephoch #2035  loss=0.129149
# ephoch #2036  loss=0.129148
# ephoch #2037  loss=0.129147
# ephoch #2038  loss=0.129145
# ephoch #2039  loss=0.129144
# ephoch #2040  loss=0.129143
# ephoch #2041  loss=0.129142
# ephoch #2042  loss=0.129141
# ephoch #2043  loss=0.12914
# ephoch #2044  loss=0.129139
# ephoch #2045  loss=0.129138
# ephoch #2046  loss=0.129137
# ephoch #2047  loss=0.129136
# ephoch #2048  loss=0.129135
# ephoch #2049  loss=0.129134
# ephoch #2050  loss=0.129133
# ephoch #2051  loss=0.129132
# ephoch #2052  loss=0.129131
# ephoch #2053  loss=0.12913
# ephoch #2054  loss=0.129129
# ephoch #2055  loss=0.129128
# ephoch #2056  loss=0.129127
# ephoch #2057  loss=0.129126
# ephoch #2058  loss=0.129125
# ephoch #2059  loss=0.129124

# %%
print(train_y[:10])
print(train_hypo_y[:10])
print(val_y[:10])
print(val_hypo_y[:10])
# Out:
# [0.51922102 1.18134123 1.36191947 0.69979926 0.94057025 0.8803775
#  1.42211222 1.24153398 1.66288321 1.42211222]
# [-0.15441487  0.73490528  1.37465449  1.20701965  0.42150218  0.79387014
#   1.08480958  1.19526258  1.20358265  1.41968094]
# [-0.44386293 -0.50405568  0.15806453  0.03767904 -0.02251371 -0.20309195
#  -0.20309195  0.39883552  0.27845003  0.57941376]
# [-0.98716156 -0.42903413 -0.3658517  -0.02603822  0.08651509 -0.36390972
#  -0.19233319 -0.19553122  0.44751692  0.39893796]

# %%
# drawing

x_axis = np.arange(len(train_loss_list))
plt.plot(x_axis,train_loss_list,"b")

plt.show()

# %%
# testing

test_y = model(test_x,w)
test_y = test_y * original_train_data_label_std + original_train_data_label_mean
print(list(np.round(test_y,2)))

with open("./submission.csv","w",newline='') as file:
  csv_writer = csv.writer(file)

  csv_writer.writerow(["id","value"])

  for index,value in enumerate(test_y):
    csv_writer.writerow([f"id_{index}",f"{value}"])
# Out:
# [20.01, 50.97, 16.4, 20.95, 5.87, 25.53, 30.63, 11.24, 37.24, 25.34, 27.15, 44.82, 26.77, 30.2, 21.99, 7.85, 40.28, 16.53, 12.01, 13.49, 11.89, 21.45, 30.23, 5.86, 45.56, 35.71, 19.65, 5.49, 24.38, 27.8, 12.94, 7.79, 12.82, 4.33, 11.85, 31.39, 14.56, 20.57, 10.2, 47.14, 36.42, 19.75, 39.69, 14.24, 34.01, 38.25, 45.97, 31.5, 41.2, 30.22, 21.86, 17.0, 31.25, 18.42, 29.83, 31.24, 18.91, 15.08, 29.5, 25.66, 8.78, 20.42, 23.09, 40.78, 36.34, 19.34, 30.93, 41.21, 20.75, 27.39, 49.06, 43.0, 32.73, 10.8, 8.1, 28.02, 51.11, 0.17, 32.55, 30.97, 6.62, 16.55, 4.1, 26.01, 5.57, 5.27, 12.13, 10.73, 11.69, 18.77, 27.71, 7.1, 9.4, 6.72, 29.75, 13.49, 13.0, 7.61, 8.58, 3.91, 8.45, 15.31, 9.3, 7.51, 8.29, 29.32, 18.44, 6.25, 11.82, 12.37, 8.7, 10.68, 11.29, 19.33, 15.22, 12.49, 6.54, 38.53, 18.97, 0.11, 1.25, 6.75, 10.92, 9.46, 5.78, 19.86, 18.01, 6.96, 14.63, 12.27, 0.97, 26.66, 12.31, 16.65, 18.38, 16.51, 6.92, 16.88, 62.82, 49.59, 22.22, 13.81, 19.07, 5.85, 8.42, 6.05, 13.88, 5.85, 10.18, 13.51, 36.52, 13.95, 18.47, 11.69, 11.91, 19.15, 17.4, 27.59, 1.64, 15.07, 34.18, 13.86, 46.01, 13.49, 26.54, 18.38, 16.82, 0.96, 54.39, 15.03, 12.67, 54.93, 16.62, 1.34, 19.48, 1.03, 5.25, 12.08, 17.3, 17.45, 34.71, 24.38, 23.49, 9.36, 5.8, 32.92, 28.8, 27.96, 11.85, 18.17, 10.45, 10.62, 24.37, 59.45, 25.18, 9.35, 50.17, 12.74, 14.32, 16.87, 99.5, 17.82, 45.75, 1.87, 45.15, 26.57, 10.13, 9.76, 50.2, 8.07, 27.49, 54.47, 15.65, 85.58, 31.34, 58.97, 71.2, 56.3, 23.52, 14.44, 24.18, 43.22, 19.42, 30.92, 32.55, 5.42, 4.53, 60.2, 22.14, 1.91, 29.81, 9.72, 16.44, 5.14, 9.03, 18.63, 9.95, 5.44, 17.42, 8.78]

# %%
# 要記得正規化回來

# %%
# csv 跳過第一列標題 (v)

# list 替換

# 先放入 numpy 再分群 (v)

# np size (v)

# np transpose (v)

# 先 transpose 再融合 (v)

# %%
# 解答
# 用 val loss 選 model
# 和 ans 比 loss

# %%
# regularation
# 5 次
